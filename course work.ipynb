# %%
import pandas as pd

# %%
df = pd.read_csv('DF2.csv', header = 0, sep=',')

# %%
df.head(5)
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
df.shape # 1
# Out:
# (10000, 10)

# %%
df.dtypes # 1
# Out:
# address        object
# city           object
# country        object
# keys           object
# latitude      float64
# longitude     float64
# name           object
# postalCode     object
# province       object
# websites       object
# dtype: object

# %%
df.info() # 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# address       10000 non-null object
# city          10000 non-null object
# country       10000 non-null object
# keys          10000 non-null object
# latitude      10000 non-null float64
# longitude     10000 non-null float64
# name          10000 non-null object
# postalCode    10000 non-null object
# province      10000 non-null object
# websites      9535 non-null object
# dtypes: float64(2), object(8)
# memory usage: 781.3+ KB

# %%
df.describe() # 1
# Out:
#            latitude     longitude
# count  10000.000000  10000.000000
# mean      37.552195    -91.056132
# std        5.050275     18.556339
# min       -6.244273   -159.378915
# 25%       34.028706    -97.412631
# 50%       38.298217    -87.660930
# 75%       41.116765    -81.458351
# max       64.840240    123.012361

# %%
df = df.drop('keys',axis=1) # 3

# %%
df.head(5)
# Out:
#                  address                    city country  latitude  longitude  \
# 0            324 Main St                 Massena      US  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House      US  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville      US  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena      US  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens      US  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# 3        McDonald's      13662       NY
# 4   OMG! Rotisserie      45701       OH
#
#                                             websites
# 0  http://mcdonalds.com,http://www.mcdonalds.com/...
# 1                              http://www.wendys.com
# 2  http://www.frischs.com,https://www.frischs.com...
# ...

# %%
df[df.latitude >= 50] # 2
# Out:
#                          address            city country   latitude  \
# 1761        607 W Willoughby Ave          Juneau      US  58.300580
# 1777       59 College Rd Ste 219       Fairbanks      US  64.840240
# 2249         11716 Old Glenn Hwy     Eagle River      US  61.326200
# 2873       1391 University Ave S       Fairbanks      US  64.835440
# 3112           1166 N Muldoon Rd       Anchorage      US  61.203697
# 3300              10447 Spur Hwy           Kenai      US  60.559630
# 3819            1859 Airport Way       Fairbanks      US  64.836600
# 6201               89 College Rd       Fairbanks      US  64.840240
# 6468             Jahnplatz 11/12           Tampa      US  52.022988
# 6779          9001 Jewel Lake Rd       Anchorage      US  61.138939
# 7025               Narva Mnt 27a         Calumet      US  58.384419
# 7302          1299 N Muldoon Rd.       Anchorage      US  61.226627
# 7348                       40/25       Worcester      US  50.447025
# ...

# %%
array = df['province'].unique() # 4

# %%
len(array) # 4
# Out:
# 52

# %%
df.latitude.max() # 5
# Out:
# 64.84024000000001

# %%
df.latitude.min() # 5
# Out:
# -6.24427307

# %%
df.rename(columns = {'name':'new_name'}, inplace = True) # 6

# %%
df.head(5)
# Out:
#                  address                    city country  latitude  longitude  \
# 0            324 Main St                 Massena      US  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House      US  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville      US  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena      US  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens      US  39.35155  -82.09728
#
#            new_name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# 3        McDonald's      13662       NY
# 4   OMG! Rotisserie      45701       OH
#
#                                             websites
# 0  http://mcdonalds.com,http://www.mcdonalds.com/...
# 1                              http://www.wendys.com
# 2  http://www.frischs.com,https://www.frischs.com...
# ...

# %%
df.iloc[1:60, 3:5].max() #7
# Out:
# latitude     48.219459
# longitude   -73.203160
# dtype: float64

# %%
df['province'].value_counts() # кол-во рест. в каждой провинции
# Out:
# CA         676
# TX         634
# OH         543
# FL         471
# IN         379
# IL         363
# NC         358
# GA         347
# MO         334
# KY         332
# VA         327
# PA         283
# NY         269
# MI         251
# TN         245
# SC         238
# LA         237
# AL         236
# WA         209
# AZ         208
# OK         208
# WI         186
# IA         166
# UT         159
# MD         159
# CO         158
# AR         151
# NJ         151
# NM         149
# MN         148
# NV         135
# MA         131
# OR         114
# SD         105
# KS         103
# ID          99
# CT          96
# WV          93
# NE          92
# MS          82
# ND          50
# ME          44
# VT          43
# WY          41
# HI          40
# NH          36
# DE          32
# MT          25
# RI          24
# DC          21
# AK          14
# Co Spgs      5
# Name: province, dtype: int64

# %%
df['province'].value_counts().head(1) # провинция с самым большим кол-вом рест.  9
# Out:
# CA    676
# Name: province, dtype: int64

# %%
df['province'].value_counts().tail(1) # провинция с самым маленьким кол-вом рест.  9
# Out:
# Co Spgs    5
# Name: province, dtype: int64

# %%
df.iloc[1:10, :].groupby('latitude').max() # 8
# Out:
#                                 address                    city country  \
# latitude
# 33.91335                205 W Church St               Batesburg      US
# 34.00598              401 N Jennings St                  Saluda      US
# 36.06107  2711 W. Kings Highway Ste. 18               Paragould      US
# 38.62736           408 Market Square Dr               Maysville      US
# 39.35155                139 Columbus Rd                  Athens      US
# 39.41760                 4182 Tonya Trl                Hamilton      US
# 39.53255                530 Clinton Ave  Washington Court House      US
# 39.86969                  590 S Main St               Englewood      US
# 44.95008          6098 State Highway 37                 Massena      US
#
#           longitude          new_name postalCode province  \
# latitude
# 33.91335  -81.53330           Wendy's      29006       SC
# 34.00598  -81.77040        McDonald's      29138       SC
# ...
